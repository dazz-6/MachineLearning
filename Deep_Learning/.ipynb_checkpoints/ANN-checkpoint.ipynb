# %%
#!pip install tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.1

# %%
## importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Churn_Modelling/Churn_Modelling.csv")
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ## Our task is to check whether the customer will continue the bank services or not. It's a binary classification problem.

# %%
## Divide the dataset into dependent and independent features.
X = dataset.iloc[:,3:13]
y = dataset.iloc[:,13]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
dataset.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
## Feature Engineering
geo = pd.get_dummies(X["Geography"],drop_first = True)
gender = pd.get_dummies(X["Gender"] ,drop_first = True)

# %%
geo
# Out:
#       Germany  Spain
# 0       False  False
# 1       False   True
# 2       False  False
# 3       False  False
# 4       False   True
# ...       ...    ...
# 9995    False  False
# 9996    False  False
# 9997    False  False
# 9998     True  False
# 9999    False  False
#
# [10000 rows x 2 columns]

# %%
gender
# Out:
#        Male
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 9995   True
# 9996   True
# 9997  False
# 9998   True
# 9999  False
#
# [10000 rows x 1 columns]

# %%
## Concatenate these variables with dataframe
X = X.drop(["Gender","Geography"], axis=1)
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 1                  1        112542.58
# 2                  0        113931.57
# 3                  0         93826.63
# 4                  1         79084.10
# ...              ...              ...
# 9995               0         96270.64
# 9996               1        101699.77
# 9997               1         42085.58
# 9998               0         92888.52
# 9999               0         38190.78
#
# [10000 rows x 8 columns]

# %%
pd.concat([X,geo,gender],axis=1)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 0                  1        101348.88    False  False  False
# 1                  1        112542.58    False   True  False
# 2                  0        113931.57    False  False  False
# 3                  0         93826.63    False  False  False
# 4                  1         79084.10    False   True  False
# ...              ...              ...      ...    ...    ...
# 9995               0         96270.64    False  False   True
# 9996               1        101699.77    False  False   True
# 9997               1         42085.58    False  False  False
# 9998               0         92888.52     True  False   True
# 9999               0         38190.78    False  False  False
#
# [10000 rows x 11 columns]

# %%
# Splitting the dataset into training set and test set
from sklearn.model_selection import train_test_split

X_train , X_test, y_train, y_test = train_test_split(X,y, test_size =0.2, random_state=0)

# %% [markdown]
# ## When FEATURE SCALING is required?
# * Distance based algo
# * Gradient Descent

# %%
## Feature Scaling

from sklearn.preprocessing import StandardScaler

Scaler= StandardScaler()
X_train = Scaler.fit_transform(X_train)
X_test =Scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ...,  0.64259497,
#         -1.03227043,  1.10643166],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  0.64259497,
#          0.9687384 , -0.74866447],
#        [-1.19119591, -0.94312892, -1.031415  , ...,  0.64259497,
#         -1.03227043,  1.48533467],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ...,  0.64259497,
#         -1.03227043,  1.41231994],
#        [-0.62420521, -0.08179119,  1.39076231, ...,  0.64259497,
#          0.9687384 ,  0.84432121],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  0.64259497,
#         -1.03227043,  0.32472465]])

# %%
X_test
# Out:
# array([[-0.55204276, -0.36890377,  1.04473698, ...,  0.64259497,
#          0.9687384 ,  1.61085707],
#        [-1.31490297,  0.10961719, -1.031415  , ...,  0.64259497,
#         -1.03227043,  0.49587037],
#        [ 0.57162971,  0.30102557,  1.04473698, ...,  0.64259497,
#          0.9687384 , -0.42478674],
#        ...,
#        [-0.74791227, -0.27319958, -1.37744033, ...,  0.64259497,
#         -1.03227043,  0.71888467],
#        [-0.00566991, -0.46460796, -0.33936434, ...,  0.64259497,
#          0.9687384 , -1.54507805],
#        [-0.79945688, -0.84742473,  1.04473698, ...,  0.64259497,
#         -1.03227043,  1.61255917]])

# %%
X_train.shape
# Out:
# (8000, 8)

# %%
## Part 2- Creating ANN
from tensorflow.keras.models import Sequential  # when we have single output and input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU, PReLU,ELU, ReLU
from tensorflow.keras.layers import Dropout  # for dropping dead neurons to reduce overfitting

# %%
## Lets initialize ANN
classifier= Sequential()

# %%
# adding input layer
classifier.add(Dense(units=11,activation='relu'))

# %%
# adding first hidden layer
classifier.add(Dense(units=7,activation='relu'))

# %%
# adding the second hidden layer 
classifier.add(Dense(units=6,activation='relu'))

# %%
## adding output layer
classifier.add(Dense(1,activation="sigmoid"))

# %%
classifier.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
import tensorflow
opt = tensorflow.keras.optimizers.Adam(learning_rate=0.01)

# %%
## Early stopping
import tensorflow as tf
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta= 0.0001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False)

# %%
model_history= classifier.fit(X_train,y_train,validation_split = 0.33, batch_size=10,epochs=1000,callbacks =early_stopping)
# Out:
# Epoch 1/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8138 - loss: 0.4293 - val_accuracy: 0.8323 - val_loss: 0.3952
# Epoch 2/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8451 - loss: 0.3734 - val_accuracy: 0.8425 - val_loss: 0.3822
# Epoch 3/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8539 - loss: 0.3658 - val_accuracy: 0.8482 - val_loss: 0.3727
# Epoch 4/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8524 - loss: 0.3590 - val_accuracy: 0.8459 - val_loss: 0.3907
# Epoch 5/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8552 - loss: 0.3597 - val_accuracy: 0.8459 - val_loss: 0.3705
# Epoch 6/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8556 - loss: 0.3569 - val_accuracy: 0.8383 - val_loss: 0.3937
# Epoch 7/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8548 - loss: 0.3548 - val_accuracy: 0.8444 - val_loss: 0.3794
# Epoch 8/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8526 - loss: 0.3549 - val_accuracy: 0.8470 - val_loss: 0.3819
# Epoch 9/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8548 - loss: 0.3546 - val_accuracy: 0.8512 - val_loss: 0.3830
# Epoch 10/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8541 - loss: 0.3537 - val_accuracy: 0.8440 - val_loss: 0.3801
# Epoch 11/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8552 - loss: 0.3532 - val_accuracy: 0.8338 - val_loss: 0.3968
# Epoch 12/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8559 - loss: 0.3534 - val_accuracy: 0.8391 - val_loss: 0.3763
# Epoch 13/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8528 - loss: 0.3527 - val_accuracy: 0.8421 - val_loss: 0.3773
# Epoch 14/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8559 - loss: 0.3532 - val_accuracy: 0.8482 - val_loss: 0.3727
# Epoch 15/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8559 - loss: 0.3521 - val_accuracy: 0.8485 - val_loss: 0.3707
# Epoch 16/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8558 - loss: 0.3492 - val_accuracy: 0.8504 - val_loss: 0.3841
# Epoch 17/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8552 - loss: 0.3519 - val_accuracy: 0.8482 - val_loss: 0.3823
# Epoch 18/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8578 - loss: 0.3489 - val_accuracy: 0.8485 - val_loss: 0.3794
# Epoch 19/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8554 - loss: 0.3488 - val_accuracy: 0.8504 - val_loss: 0.3802
# Epoch 20/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8586 - loss: 0.3482 - val_accuracy: 0.8504 - val_loss: 0.3793
# Epoch 21/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8587 - loss: 0.3468 - val_accuracy: 0.8463 - val_loss: 0.3973
# Epoch 22/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8595 - loss: 0.3467 - val_accuracy: 0.8459 - val_loss: 0.3805
# Epoch 23/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8556 - loss: 0.3448 - val_accuracy: 0.8531 - val_loss: 0.3816
# Epoch 24/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8584 - loss: 0.3456 - val_accuracy: 0.8493 - val_loss: 0.3777
# Epoch 25/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8545 - loss: 0.3454 - val_accuracy: 0.8485 - val_loss: 0.3784
# Epoch 25: early stopping

# %%
model_history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# summary history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history["val_accuracy"])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(["train","test"], loc="upper left")
plt.show()
