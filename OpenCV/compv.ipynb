# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('imgData/cat.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (350, 350, 3)

# %% [markdown]
# ### Opencv givve diff order of channels
# ### MATPLOTLIB : RGB
# ### OPENCV: BGR

# %%
plt.imshow(img)

# %%
IMG = cv2.cvtColor(img ,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(IMG)
