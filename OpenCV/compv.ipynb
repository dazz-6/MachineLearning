# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('imgData/cat.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[234, 255, 254],
#         [236, 254, 253],
#         [240, 254, 254],
#         ...,
#         [ 75,  66,  67],
#         [ 67,  62,  63],
#         [ 66,  64,  64]],
#
#        [[232, 254, 252],
#         [235, 254, 253],
#         [240, 254, 254],
#         ...,
#         [ 54,  47,  43],
#         [ 55,  49,  46],
#         [ 57,  52,  48]],
#
#        [[232, 253, 252],
#         [235, 254, 253],
#         [240, 254, 254],
#         ...,
#         [ 67,  49,  43],
#         [ 67,  50,  44],
#         [ 71,  54,  48]],
#
#        ...,
#
#        [[136, 195, 236],
#         [135, 195, 235],
#         [133, 195, 235],
#         ...,
#         [ 46,  58,  83],
#         [ 37,  49,  74],
#         [ 51,  63,  89]],
#
#        [[137, 193, 237],
#         [124, 185, 226],
#         [121, 185, 225],
#         ...,
#         [ 33,  45,  70],
#         [ 49,  60,  86],
#         [ 61,  73,  98]],
#
#        [[129, 188, 233],
#         [122, 184, 226],
#         [128, 191, 233],
# ...
